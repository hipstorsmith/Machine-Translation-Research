# %%
# %tensorflow_version 1.x
import pickle as pkl
import numpy as np
import tensorflow as tf
from matplotlib import pyplot as plt
from tensorflow.python.keras.preprocessing.text import Tokenizer
from tensorflow.python.keras.preprocessing.sequence import pad_sequences
from tensorflow.python.keras.utils import to_categorical
from tensorflow.python.keras.utils.vis_utils import plot_model
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import LSTM, Dense, Embedding, RepeatVector, TimeDistributed
from tensorflow.python.keras.callbacks import ModelCheckpoint
import tensorflow.python.keras.backend as K
import gc
# Out:
# TensorFlow 1.x selected.

# %%
# Imports for colab
from google.colab import drive
drive.mount('/content/gdrive')

dirname = '/content/gdrive/My Drive/Colab Notebooks/'
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Preparations for training

# %% [markdown]
# ## Load clean dataset

# %%
def load_clean_sentences(filename):
    return pkl.load(open(filename, 'rb'))

# %% [markdown]
# ## Fit a tokenizer

# %%
def create_tokenizer(lines, num_words=None, filters='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n', lower=True, oov_token=None):
    tokenizer = Tokenizer(num_words=num_words, filters=filters, lower=lower, oov_token=oov_token)
    tokenizer.fit_on_texts(lines)
    return tokenizer

# %% [markdown]
# ## Compute max length of sentence

# %%
def max_length(lines):
    return max(len(line.split()) for line in lines)

# %% [markdown]
# ## Encode and pad sequences

# %%
def encode_sequences(tokenizer, length, lines):
    # Encode sequences
    X = tokenizer.texts_to_sequences(lines)

    # Pad sequences with zeros
    X = pad_sequences(X, maxlen=length, padding='post')

    return X

# %% [markdown]
# ## One-hot encoding

# %% [markdown]
# One-hot encoding is required for target translation, because NN have to predict probability of next word

# %%
def encode_output(sequences, vocab_size):
    y = np.zeros([sequences.shape[0], sequences.shape[1], vocab_size], dtype=np.int8)
    for i in range(sequences.shape[0]):
        y[i] = to_categorical(sequences[i], num_classes=vocab_size, dtype=np.int8)
    return y

# %% [markdown]
# ## Define model

# %%
def define_model(source_vocab, target_vocab, source_timesteps, target_timesteps, n_units):
    model = Sequential()
    # Embedding layer: source_vocab - input vocabulary, n_units - number on neurons in layer, mask_zero - output 0 if input is 0
    model.add(Embedding(source_vocab, n_units, input_length=source_timesteps, mask_zero=True))
    model.add(LSTM(n_units))
    # Repeats input target_timesteps times
    model.add(RepeatVector(target_timesteps))
    model.add(LSTM(n_units, return_sequences=True))
    model.add(TimeDistributed(Dense(target_vocab, activation='softmax')))
    return model

# %% [markdown]
# # Training
# X - data, y - target

# %%
# Load datasets

dataset = load_clean_sentences(dirname + 'english-russian-100k-both.pkl')
len_data = len(dataset)
train = load_clean_sentences(dirname + 'english-russian-100k-train.pkl')
test = load_clean_sentences(dirname + 'english-russian-100k-test.pkl')

# %%
# Prepare english tokenizer
base_tok_name = str(len_data//1000) + 'k'

eng_tokenizer = create_tokenizer(dataset[:, 0])
eng_vocab_size = len(eng_tokenizer.word_index) + 1 #+1 because of <EOS> token
eng_length = max_length(dataset[:, 0])
print('English vocabulary size: %d' % eng_vocab_size)
print('English max sentence length: %d' % eng_length)

pkl.dump(eng_tokenizer, open(dirname + 'en_tokenizer_%s' % base_tok_name, 'wb'))
# Out:
# English vocabulary size: 7313
# English max sentence length: 7

# %%
# Prepare russian tokenizer
rus_tokenizer = create_tokenizer(dataset[:, 1])
rus_vocab_size = len(rus_tokenizer.word_index) + 1
rus_length = max_length(dataset[:, 1])
print('Russian vocabulary size: %d' % rus_vocab_size)
print('Russian max sentence length: %d' % rus_length)

pkl.dump(rus_tokenizer, open(dirname + 'ru_tokenizer_%s' % base_tok_name, 'wb'))
# Out:
# Russian vocabulary size: 20884
# Russian max sentence length: 11

# %%
# Prepare training data
X_train = encode_sequences(eng_tokenizer, eng_length, train[:, 0])

# %%
y_train = encode_sequences(rus_tokenizer, rus_length, train[:, 1])

# %%
y_train = encode_output(y_train, rus_vocab_size)

# %%
# Prepare validation data
X_val = encode_sequences(eng_tokenizer, eng_length, test[:, 0])
y_val = encode_sequences(rus_tokenizer, rus_length, test[:, 1])
y_val = encode_output(y_val, rus_vocab_size)

# %%
# Define model
K.clear_session()
model = define_model(eng_vocab_size, rus_vocab_size, eng_length, rus_length, 256)
model.compile(optimizer='adam', loss='categorical_crossentropy')

# %%
# Model overview
print(model.summary())
plot_model(model, to_file=dirname + 'model_basic.png', show_shapes=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 7, 256)            1872128
# _________________________________________________________________
# lstm (LSTM)                  (None, 256)               525312
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 11, 256)           0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 11, 256)           525312
# _________________________________________________________________
# time_distributed (TimeDistri (None, 11, 20884)         5367188
# =================================================================
# Total params: 8,289,940
# Trainable params: 8,289,940
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#Fit model
epochs = 100
base_name = '%dk_%de' % ((len_data//1000, epochs))

filename = dirname + 'model_basic_%s.h5' % base_name
checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
history = model.fit(X_train, y_train, epochs=epochs, batch_size=64, validation_data=(X_val, y_val), callbacks=[checkpoint], verbose=2)
# Out:
# Train on 90000 samples, validate on 10000 samples
# Epoch 1/100
#
# Epoch 00001: val_loss improved from inf to 2.09347, saving model to /content/gdrive/My Drive/Colab Notebooks/model_basic_100k_100e.h5
# 90000/90000 - 102s - loss: 2.4403 - val_loss: 2.0935
# Epoch 2/100
#
# Epoch 00002: val_loss improved from 2.09347 to 1.69408, saving model to /content/gdrive/My Drive/Colab Notebooks/model_basic_100k_100e.h5
# 90000/90000 - 96s - loss: 1.8705 - val_loss: 1.6941
# Epoch 3/100
#
# Epoch 00003: val_loss improved from 1.69408 to 1.39682, saving model to /content/gdrive/My Drive/Colab Notebooks/model_basic_100k_100e.h5
# 90000/90000 - 94s - loss: 1.4859 - val_loss: 1.3968
# Epoch 4/100
#
# Epoch 00004: val_loss improved from 1.39682 to 1.18669, saving model to /content/gdrive/My Drive/Colab Notebooks/model_basic_100k_100e.h5
# 90000/90000 - 94s - loss: 1.1823 - val_loss: 1.1867
# Epoch 5/100
#
# Epoch 00005: val_loss improved from 1.18669 to 1.04761, saving model to /content/gdrive/My Drive/Colab Notebooks/model_basic_100k_100e.h5
# 90000/90000 - 101s - loss: 0.9489 - val_loss: 1.0476
# Epoch 6/100
#
# Epoch 00006: val_loss improved from 1.04761 to 0.95896, saving model to /content/gdrive/My Drive/Colab Notebooks/model_basic_100k_100e.h5
# 90000/90000 - 100s - loss: 0.7742 - val_loss: 0.9590
# Epoch 7/100
#
# Epoch 00007: val_loss improved from 0.95896 to 0.90144, saving model to /content/gdrive/My Drive/Colab Notebooks/model_basic_100k_100e.h5
# 90000/90000 - 99s - loss: 0.6463 - val_loss: 0.9014
# Epoch 8/100
#
# Epoch 00008: val_loss improved from 0.90144 to 0.86947, saving model to /content/gdrive/My Drive/Colab Notebooks/model_basic_100k_100e.h5
# 90000/90000 - 98s - loss: 0.5554 - val_loss: 0.8695
# Epoch 9/100
#
# Epoch 00009: val_loss improved from 0.86947 to 0.85105, saving model to /content/gdrive/My Drive/Colab Notebooks/model_basic_100k_100e.h5
# 90000/90000 - 103s - loss: 0.4907 - val_loss: 0.8510
# Epoch 10/100
#
# Epoch 00010: val_loss improved from 0.85105 to 0.83998, saving model to /content/gdrive/My Drive/Colab Notebooks/model_basic_100k_100e.h5
# 90000/90000 - 101s - loss: 0.4443 - val_loss: 0.8400
# Epoch 11/100
#
# Epoch 00011: val_loss improved from 0.83998 to 0.83476, saving model to /content/gdrive/My Drive/Colab Notebooks/model_basic_100k_100e.h5
# 90000/90000 - 100s - loss: 0.4101 - val_loss: 0.8348
# Epoch 12/100
#
# Epoch 00012: val_loss improved from 0.83476 to 0.83410, saving model to /content/gdrive/My Drive/Colab Notebooks/model_basic_100k_100e.h5
# 90000/90000 - 99s - loss: 0.3825 - val_loss: 0.8341
# Epoch 13/100
#
# Epoch 00013: val_loss improved from 0.83410 to 0.83259, saving model to /content/gdrive/My Drive/Colab Notebooks/model_basic_100k_100e.h5
# 90000/90000 - 101s - loss: 0.3606 - val_loss: 0.8326
# Epoch 14/100
#
# Epoch 00014: val_loss did not improve from 0.83259
# 90000/90000 - 101s - loss: 0.3422 - val_loss: 0.8337
# Epoch 15/100
#
# Epoch 00015: val_loss did not improve from 0.83259
# 90000/90000 - 97s - loss: 0.3266 - val_loss: 0.8402
# Epoch 16/100
#
# Epoch 00016: val_loss did not improve from 0.83259
# 90000/90000 - 96s - loss: 0.3133 - val_loss: 0.8410
# Epoch 17/100
#
# Epoch 00017: val_loss did not improve from 0.83259
# 90000/90000 - 96s - loss: 0.3023 - val_loss: 0.8459
# Epoch 18/100
#
# Epoch 00018: val_loss did not improve from 0.83259
# 90000/90000 - 95s - loss: 0.2923 - val_loss: 0.8519
# Epoch 19/100
#
# Epoch 00019: val_loss did not improve from 0.83259
# 90000/90000 - 96s - loss: 0.2836 - val_loss: 0.8579
# Epoch 20/100
#
# Epoch 00020: val_loss did not improve from 0.83259
# 90000/90000 - 95s - loss: 0.2763 - val_loss: 0.8614
# Epoch 21/100
#
# Epoch 00021: val_loss did not improve from 0.83259
# 90000/90000 - 93s - loss: 0.2698 - val_loss: 0.8669
# Epoch 22/100
#
# Epoch 00022: val_loss did not improve from 0.83259
# 90000/90000 - 94s - loss: 0.2638 - val_loss: 0.8682
# Epoch 23/100
#
# Epoch 00023: val_loss did not improve from 0.83259
# 90000/90000 - 94s - loss: 0.2588 - val_loss: 0.8787
# Epoch 24/100
#
# Epoch 00024: val_loss did not improve from 0.83259
# 90000/90000 - 95s - loss: 0.2542 - val_loss: 0.8817
# Epoch 25/100
#
# Epoch 00025: val_loss did not improve from 0.83259
# 90000/90000 - 95s - loss: 0.2498 - val_loss: 0.8867
# Epoch 26/100
#
# Epoch 00026: val_loss did not improve from 0.83259
# 90000/90000 - 95s - loss: 0.2459 - val_loss: 0.8914
# Epoch 27/100
#
# Epoch 00027: val_loss did not improve from 0.83259
# 90000/90000 - 95s - loss: 0.2427 - val_loss: 0.8948
# Epoch 28/100
#
# Epoch 00028: val_loss did not improve from 0.83259
# 90000/90000 - 95s - loss: 0.2393 - val_loss: 0.9004
# Epoch 29/100
#
# Epoch 00029: val_loss did not improve from 0.83259
# 90000/90000 - 95s - loss: 0.2370 - val_loss: 0.9026
# Epoch 30/100
#
# Epoch 00030: val_loss did not improve from 0.83259
# 90000/90000 - 95s - loss: 0.2348 - val_loss: 0.9061
# Epoch 31/100
#
# Epoch 00031: val_loss did not improve from 0.83259
# 90000/90000 - 95s - loss: 0.2321 - val_loss: 0.9086
# Epoch 32/100
#
# Epoch 00032: val_loss did not improve from 0.83259
# 90000/90000 - 95s - loss: 0.2298 - val_loss: 0.9158
# Epoch 33/100
#
# Epoch 00033: val_loss did not improve from 0.83259
# 90000/90000 - 95s - loss: 0.2275 - val_loss: 0.9212
# Epoch 34/100
#
# Epoch 00034: val_loss did not improve from 0.83259
# 90000/90000 - 95s - loss: 0.2265 - val_loss: 0.9246
# Epoch 35/100
#
# Epoch 00035: val_loss did not improve from 0.83259
# 90000/90000 - 95s - loss: 0.2242 - val_loss: 0.9258
# Epoch 36/100
#
# Epoch 00036: val_loss did not improve from 0.83259
# 90000/90000 - 95s - loss: 0.2229 - val_loss: 0.9315
# Epoch 37/100
#
# Epoch 00037: val_loss did not improve from 0.83259
# 90000/90000 - 95s - loss: 0.2216 - val_loss: 0.9334
# Epoch 38/100
#
# Epoch 00038: val_loss did not improve from 0.83259
# 90000/90000 - 95s - loss: 0.2200 - val_loss: 0.9366
# Epoch 39/100
#
# Epoch 00039: val_loss did not improve from 0.83259
# 90000/90000 - 94s - loss: 0.2194 - val_loss: 0.9391
# Epoch 40/100
#
# Epoch 00040: val_loss did not improve from 0.83259
# 90000/90000 - 94s - loss: 0.2176 - val_loss: 0.9418
# Epoch 41/100
#
# Epoch 00041: val_loss did not improve from 0.83259
# 90000/90000 - 94s - loss: 0.2169 - val_loss: 0.9442
# Epoch 42/100
#
# Epoch 00042: val_loss did not improve from 0.83259
# 90000/90000 - 94s - loss: 0.2158 - val_loss: 0.9435
# Epoch 43/100
#
# Epoch 00043: val_loss did not improve from 0.83259
# 90000/90000 - 94s - loss: 0.2149 - val_loss: 0.9505
# Epoch 44/100
#
# Epoch 00044: val_loss did not improve from 0.83259
# 90000/90000 - 94s - loss: 0.2138 - val_loss: 0.9510
# Epoch 45/100
#
# Epoch 00045: val_loss did not improve from 0.83259
# 90000/90000 - 94s - loss: 0.2124 - val_loss: 0.9567
# Epoch 46/100
#
# Epoch 00046: val_loss did not improve from 0.83259
# 90000/90000 - 94s - loss: 0.2126 - val_loss: 0.9572
# Epoch 47/100
#
# Epoch 00047: val_loss did not improve from 0.83259
# 90000/90000 - 94s - loss: 0.2114 - val_loss: 0.9591
# Epoch 48/100
#
# Epoch 00048: val_loss did not improve from 0.83259
# 90000/90000 - 94s - loss: 0.2108 - val_loss: 0.9619
# Epoch 49/100
#
# Epoch 00049: val_loss did not improve from 0.83259
# 90000/90000 - 94s - loss: 0.2099 - val_loss: 0.9652
# Epoch 50/100
#
# Epoch 00050: val_loss did not improve from 0.83259
# 90000/90000 - 94s - loss: 0.2093 - val_loss: 0.9653
# Epoch 51/100
#
# Epoch 00051: val_loss did not improve from 0.83259
# 90000/90000 - 94s - loss: 0.2091 - val_loss: 0.9678
# Epoch 52/100
#
# Epoch 00052: val_loss did not improve from 0.83259
# 90000/90000 - 94s - loss: 0.2081 - val_loss: 0.9719
# Epoch 53/100
#
# Epoch 00053: val_loss did not improve from 0.83259
# 90000/90000 - 94s - loss: 0.2078 - val_loss: 0.9732
# Epoch 54/100
#
# Epoch 00054: val_loss did not improve from 0.83259
# 90000/90000 - 94s - loss: 0.2067 - val_loss: 0.9743
# Epoch 55/100
#
# Epoch 00055: val_loss did not improve from 0.83259
# 90000/90000 - 94s - loss: 0.2063 - val_loss: 0.9777
# Epoch 56/100
#
# Epoch 00056: val_loss did not improve from 0.83259
# 90000/90000 - 95s - loss: 0.2058 - val_loss: 0.9804
# Epoch 57/100
#
# Epoch 00057: val_loss did not improve from 0.83259
# 90000/90000 - 94s - loss: 0.2056 - val_loss: 0.9810
# Epoch 58/100
#
# Epoch 00058: val_loss did not improve from 0.83259
# 90000/90000 - 94s - loss: 0.2043 - val_loss: 0.9786
# Epoch 59/100
#
# Epoch 00059: val_loss did not improve from 0.83259
# 90000/90000 - 94s - loss: 0.2048 - val_loss: 0.9824
# Epoch 60/100
#
# Epoch 00060: val_loss did not improve from 0.83259
# 90000/90000 - 94s - loss: 0.2042 - val_loss: 0.9867
# Epoch 61/100
#
# Epoch 00061: val_loss did not improve from 0.83259
# 90000/90000 - 94s - loss: 0.2037 - val_loss: 0.9893
# Epoch 62/100
#
# Epoch 00062: val_loss did not improve from 0.83259
# 90000/90000 - 94s - loss: 0.2032 - val_loss: 0.9861
# Epoch 63/100
#
# Epoch 00063: val_loss did not improve from 0.83259
# 90000/90000 - 94s - loss: 0.2023 - val_loss: 0.9922
# Epoch 64/100
#
# Epoch 00064: val_loss did not improve from 0.83259
# 90000/90000 - 94s - loss: 0.2019 - val_loss: 0.9943
# Epoch 65/100
#
# Epoch 00065: val_loss did not improve from 0.83259
# 90000/90000 - 94s - loss: 0.2024 - val_loss: 0.9961
# Epoch 66/100
#
# Epoch 00066: val_loss did not improve from 0.83259
# 90000/90000 - 95s - loss: 0.2015 - val_loss: 0.9991
# Epoch 67/100
#
# Epoch 00067: val_loss did not improve from 0.83259
# 90000/90000 - 94s - loss: 0.2011 - val_loss: 1.0011
# Epoch 68/100
#
# Epoch 00068: val_loss did not improve from 0.83259
# 90000/90000 - 94s - loss: 0.2004 - val_loss: 1.0043
# Epoch 69/100
#
# Epoch 00069: val_loss did not improve from 0.83259
# 90000/90000 - 94s - loss: 0.2005 - val_loss: 0.9975
# Epoch 70/100
#
# Epoch 00070: val_loss did not improve from 0.83259
# 90000/90000 - 94s - loss: 0.1999 - val_loss: 1.0031
# Epoch 71/100
#
# Epoch 00071: val_loss did not improve from 0.83259
# 90000/90000 - 94s - loss: 0.1998 - val_loss: 1.0040
# Epoch 72/100
#
# Epoch 00072: val_loss did not improve from 0.83259
# 90000/90000 - 96s - loss: 0.1994 - val_loss: 1.0075
# Epoch 73/100
#
# Epoch 00073: val_loss did not improve from 0.83259
# 90000/90000 - 98s - loss: 0.1992 - val_loss: 1.0059
# Epoch 74/100
#
# Epoch 00074: val_loss did not improve from 0.83259
# 90000/90000 - 95s - loss: 0.1985 - val_loss: 1.0088
# Epoch 75/100
#
# Epoch 00075: val_loss did not improve from 0.83259
# 90000/90000 - 95s - loss: 0.1983 - val_loss: 1.0064
# Epoch 76/100
#
# Epoch 00076: val_loss did not improve from 0.83259
# 90000/90000 - 95s - loss: 0.1979 - val_loss: 1.0084
# Epoch 77/100
#
# Epoch 00077: val_loss did not improve from 0.83259
# 90000/90000 - 95s - loss: 0.1979 - val_loss: 1.0148
# Epoch 78/100
#
# Epoch 00078: val_loss did not improve from 0.83259
# 90000/90000 - 95s - loss: 0.1977 - val_loss: 1.0168
# Epoch 79/100
#
# Epoch 00079: val_loss did not improve from 0.83259
# 90000/90000 - 94s - loss: 0.1970 - val_loss: 1.0180
# Epoch 80/100
#
# Epoch 00080: val_loss did not improve from 0.83259
# 90000/90000 - 94s - loss: 0.1973 - val_loss: 1.0187
# Epoch 81/100
#
# Epoch 00081: val_loss did not improve from 0.83259
# 90000/90000 - 94s - loss: 0.1969 - val_loss: 1.0175
# Epoch 82/100
#
# Epoch 00082: val_loss did not improve from 0.83259
# 90000/90000 - 94s - loss: 0.1963 - val_loss: 1.0146
# Epoch 83/100
#
# Epoch 00083: val_loss did not improve from 0.83259
# 90000/90000 - 94s - loss: 0.1963 - val_loss: 1.0172
# Epoch 84/100
#
# Epoch 00084: val_loss did not improve from 0.83259
# 90000/90000 - 94s - loss: 0.1962 - val_loss: 1.0223
# Epoch 85/100
#
# Epoch 00085: val_loss did not improve from 0.83259
# 90000/90000 - 94s - loss: 0.1956 - val_loss: 1.0204
# Epoch 86/100
#
# Epoch 00086: val_loss did not improve from 0.83259
# 90000/90000 - 94s - loss: 0.1958 - val_loss: 1.0238
# Epoch 87/100
#
# Epoch 00087: val_loss did not improve from 0.83259
# 90000/90000 - 94s - loss: 0.1953 - val_loss: 1.0219
# Epoch 88/100
#
# Epoch 00088: val_loss did not improve from 0.83259
# 90000/90000 - 94s - loss: 0.1944 - val_loss: 1.0264
# Epoch 89/100
#
# Epoch 00089: val_loss did not improve from 0.83259
# 90000/90000 - 93s - loss: 0.1952 - val_loss: 1.0269
# Epoch 90/100
#
# Epoch 00090: val_loss did not improve from 0.83259
# 90000/90000 - 93s - loss: 0.1950 - val_loss: 1.0268
# Epoch 91/100
#
# Epoch 00091: val_loss did not improve from 0.83259
# 90000/90000 - 93s - loss: 0.1943 - val_loss: 1.0331
# Epoch 92/100
#
# Epoch 00092: val_loss did not improve from 0.83259
# 90000/90000 - 94s - loss: 0.1947 - val_loss: 1.0310
# Epoch 93/100
#
# Epoch 00093: val_loss did not improve from 0.83259
# 90000/90000 - 93s - loss: 0.1943 - val_loss: 1.0307
# Epoch 94/100
#
# Epoch 00094: val_loss did not improve from 0.83259
# 90000/90000 - 94s - loss: 0.1934 - val_loss: 1.0333
# Epoch 95/100
#
# Epoch 00095: val_loss did not improve from 0.83259
# 90000/90000 - 93s - loss: 0.1935 - val_loss: 1.0345
# Epoch 96/100
#
# Epoch 00096: val_loss did not improve from 0.83259
# 90000/90000 - 94s - loss: 0.1936 - val_loss: 1.0322
# Epoch 97/100
#
# Epoch 00097: val_loss did not improve from 0.83259
# 90000/90000 - 95s - loss: 0.1933 - val_loss: 1.0337
# Epoch 98/100
#
# Epoch 00098: val_loss did not improve from 0.83259
# 90000/90000 - 96s - loss: 0.1930 - val_loss: 1.0378
# Epoch 99/100
#
# Epoch 00099: val_loss did not improve from 0.83259
# 90000/90000 - 94s - loss: 0.1928 - val_loss: 1.0325
# Epoch 100/100
#
# Epoch 00100: val_loss did not improve from 0.83259
# 90000/90000 - 94s - loss: 0.1927 - val_loss: 1.0355

# %% [markdown]
# ## Overview

# %%
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.savefig(dirname + 'model_basic_%s_loss.png' % base_name)
plt.show()
