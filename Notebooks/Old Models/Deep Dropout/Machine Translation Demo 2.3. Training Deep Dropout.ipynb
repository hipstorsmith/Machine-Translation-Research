# %%
# %tensorflow_version 1.x
import pickle as pkl
import numpy as np
import tensorflow as tf
from matplotlib import pyplot as plt
from tensorflow.python.keras.preprocessing.text import Tokenizer
from tensorflow.python.keras.preprocessing.sequence import pad_sequences
from tensorflow.python.keras.utils import to_categorical
from tensorflow.python.keras.utils.vis_utils import plot_model
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import LSTM, Dense, Embedding, RepeatVector, TimeDistributed, Bidirectional
from tensorflow.python.keras.callbacks import ModelCheckpoint
import tensorflow.python.keras.backend as K
import gc
# Out:
# TensorFlow 1.x selected.

# %%
# Imports for colab
from google.colab import drive
drive.mount('/content/gdrive')

dirname = '/content/gdrive/My Drive/Colab Notebooks/'
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# # Preparations for training

# %% [markdown]
# ## Load clean dataset

# %%
def load_clean_sentences(filename):
    return pkl.load(open(filename, 'rb'))

# %% [markdown]
# ## Fit a tokenizer

# %%
def create_tokenizer(lines, num_words=None, filters='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n', lower=True, oov_token=None):
    tokenizer = Tokenizer(num_words=num_words, filters=filters, lower=lower, oov_token=oov_token)
    tokenizer.fit_on_texts(lines)
    return tokenizer

# %% [markdown]
# ## Compute max length of sentence

# %%
def max_length(lines):
    return max(len(line.split()) for line in lines)

# %% [markdown]
# ## Encode and pad sequences

# %%
def encode_sequences(tokenizer, length, lines):
    # Encode sequences
    X = tokenizer.texts_to_sequences(lines)

    # Pad sequences with zeros
    X = pad_sequences(X, maxlen=length, padding='post')

    return X

# %% [markdown]
# ## One-hot encoding

# %% [markdown]
# One-hot encoding is required for target translation, because NN have to predict probability of next word

# %%
def encode_output(sequences, vocab_size):
    y = np.zeros([sequences.shape[0], sequences.shape[1], vocab_size], dtype=np.int8)
    for i in range(sequences.shape[0]):
        y[i] = to_categorical(sequences[i], num_classes=vocab_size, dtype=np.int8)
    return y

# %% [markdown]
# ## Define model

# %%
def define_model(source_vocab, target_vocab, source_timesteps, target_timesteps, n_units):
    model = Sequential()
    # Embedding layer: source_vocab - input vocabulary, n_units - number on neurons in layer, mask_zero - output 0 if input is 0
    model.add(Embedding(source_vocab, n_units, input_length=source_timesteps, mask_zero=True))
    model.add(Bidirectional(LSTM(n_units, dropout=0.2, return_sequences=True)))
    model.add(Bidirectional(LSTM(n_units, dropout=0.2)))
    # Repeats input target_timesteps times
    model.add(RepeatVector(target_timesteps))
    model.add(LSTM(n_units, return_sequences=True, dropout=0.2))
    model.add(LSTM(n_units, return_sequences=True, dropout=0.2))
    model.add(LSTM(n_units, return_sequences=True, dropout=0.2))
    model.add(LSTM(n_units, return_sequences=True, dropout=0.2))
    model.add(TimeDistributed(Dense(target_vocab, activation='softmax')))
    return model

# %% [markdown]
# # Training
# X - data, y - target

# %%
# Load datasets

dataset = load_clean_sentences(dirname + 'english-russian-100k-both.pkl')
len_data = len(dataset)
train = load_clean_sentences(dirname + 'english-russian-100k-train.pkl')
test = load_clean_sentences(dirname + 'english-russian-100k-test.pkl')

# %%
# Prepare english tokenizer
base_tok_name = str(len_data//1000) + 'k'

eng_tokenizer = create_tokenizer(dataset[:, 0])
eng_vocab_size = len(eng_tokenizer.word_index) + 1 #+1 because of <EOS> token
eng_length = max_length(dataset[:, 0])
print('English vocabulary size: %d' % eng_vocab_size)
print('English max sentence length: %d' % eng_length)

pkl.dump(eng_tokenizer, open(dirname + 'en_tokenizer_%s' % base_tok_name, 'wb'))
# Out:
# English vocabulary size: 7313
# English max sentence length: 7

# %%
# Prepare russian tokenizer
rus_tokenizer = create_tokenizer(dataset[:, 1])
rus_vocab_size = len(rus_tokenizer.word_index) + 1
rus_length = max_length(dataset[:, 1])
print('Russian vocabulary size: %d' % rus_vocab_size)
print('Russian max sentence length: %d' % rus_length)

pkl.dump(rus_tokenizer, open(dirname + 'ru_tokenizer_%s' % base_tok_name, 'wb'))
# Out:
# Russian vocabulary size: 20884
# Russian max sentence length: 11

# %%
# Prepare training data
X_train = encode_sequences(eng_tokenizer, eng_length, train[:, 0])

# %%
y_train = encode_sequences(rus_tokenizer, rus_length, train[:, 1])

# %%
y_train = encode_output(y_train, rus_vocab_size)

# %%
# Prepare validation data
X_val = encode_sequences(eng_tokenizer, eng_length, test[:, 0])
y_val = encode_sequences(rus_tokenizer, rus_length, test[:, 1])
y_val = encode_output(y_val, rus_vocab_size)

# %%
#Clean-up some memory
del dataset, train, test

# %%
# Define model
K.clear_session()
model = define_model(eng_vocab_size, rus_vocab_size, eng_length, rus_length, 256)
model.compile(optimizer='adam', loss='categorical_crossentropy')
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/keras/initializers.py:119: calling RandomUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/init_ops.py:97: calling Orthogonal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/keras/backend.py:3994: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
# Model overview
print(model.summary())
plot_model(model, to_file=dirname + 'model_deep_dropout.png', show_shapes=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 7, 256)            1872128
# _________________________________________________________________
# bidirectional (Bidirectional (None, 7, 512)            1050624
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 512)               1574912
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 11, 512)           0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 11, 256)           787456
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 11, 256)           525312
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 11, 256)           525312
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 11, 256)           525312
# _________________________________________________________________
# time_distributed (TimeDistri (None, 11, 20884)         5367188
# =================================================================
# Total params: 12,228,244
# Trainable params: 12,228,244
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#Fit model
epochs = 100
base_name = '%dk_%de' % ((len_data//1000, epochs))

filename = dirname + 'model_deep_dropout_%s.h5' % base_name
checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
history = model.fit(X_train, y_train, epochs=epochs, batch_size=1024, validation_data=(X_val, y_val), callbacks=[checkpoint], verbose=2)
# Out:
# Train on 90000 samples, validate on 10000 samples
# Epoch 1/100
#
# Epoch 00001: val_loss improved from inf to 2.69380, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 150s - loss: 3.9450 - val_loss: 2.6938
# Epoch 2/100
#
# Epoch 00002: val_loss improved from 2.69380 to 2.54130, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 142s - loss: 2.6153 - val_loss: 2.5413
# Epoch 3/100
#
# Epoch 00003: val_loss improved from 2.54130 to 2.45172, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 139s - loss: 2.4871 - val_loss: 2.4517
# Epoch 4/100
#
# Epoch 00004: val_loss improved from 2.45172 to 2.39128, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 136s - loss: 2.4108 - val_loss: 2.3913
# Epoch 5/100
#
# Epoch 00005: val_loss improved from 2.39128 to 2.34947, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 137s - loss: 2.3601 - val_loss: 2.3495
# Epoch 6/100
#
# Epoch 00006: val_loss improved from 2.34947 to 2.32532, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 142s - loss: 2.3233 - val_loss: 2.3253
# Epoch 7/100
#
# Epoch 00007: val_loss improved from 2.32532 to 2.30509, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 138s - loss: 2.3002 - val_loss: 2.3051
# Epoch 8/100
#
# Epoch 00008: val_loss improved from 2.30509 to 2.29326, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 138s - loss: 2.2824 - val_loss: 2.2933
# Epoch 9/100
#
# Epoch 00009: val_loss improved from 2.29326 to 2.27941, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 138s - loss: 2.2678 - val_loss: 2.2794
# Epoch 10/100
#
# Epoch 00010: val_loss improved from 2.27941 to 2.26224, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 138s - loss: 2.2565 - val_loss: 2.2622
# Epoch 11/100
#
# Epoch 00011: val_loss improved from 2.26224 to 2.23480, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 137s - loss: 2.2364 - val_loss: 2.2348
# Epoch 12/100
#
# Epoch 00012: val_loss improved from 2.23480 to 2.22184, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 138s - loss: 2.2176 - val_loss: 2.2218
# Epoch 13/100
#
# Epoch 00013: val_loss improved from 2.22184 to 2.20753, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 138s - loss: 2.2028 - val_loss: 2.2075
# Epoch 14/100
#
# Epoch 00014: val_loss improved from 2.20753 to 2.19700, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 140s - loss: 2.1910 - val_loss: 2.1970
# Epoch 15/100
#
# Epoch 00015: val_loss improved from 2.19700 to 2.19119, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 138s - loss: 2.1820 - val_loss: 2.1912
# Epoch 16/100
#
# Epoch 00016: val_loss improved from 2.19119 to 2.17340, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 138s - loss: 2.1674 - val_loss: 2.1734
# Epoch 17/100
#
# Epoch 00017: val_loss improved from 2.17340 to 2.16007, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 138s - loss: 2.1499 - val_loss: 2.1601
# Epoch 18/100
#
# Epoch 00018: val_loss improved from 2.16007 to 2.15190, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 139s - loss: 2.1326 - val_loss: 2.1519
# Epoch 19/100
#
# Epoch 00019: val_loss improved from 2.15190 to 2.14391, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 138s - loss: 2.1223 - val_loss: 2.1439
# Epoch 20/100
#
# Epoch 00020: val_loss improved from 2.14391 to 2.13784, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 139s - loss: 2.1120 - val_loss: 2.1378
# Epoch 21/100
#
# Epoch 00021: val_loss improved from 2.13784 to 2.12764, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 139s - loss: 2.1014 - val_loss: 2.1276
# Epoch 22/100
#
# Epoch 00022: val_loss improved from 2.12764 to 2.11854, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 138s - loss: 2.0906 - val_loss: 2.1185
# Epoch 23/100
#
# Epoch 00023: val_loss improved from 2.11854 to 2.10699, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 139s - loss: 2.0730 - val_loss: 2.1070
# Epoch 24/100
#
# Epoch 00024: val_loss improved from 2.10699 to 2.08604, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 139s - loss: 2.0573 - val_loss: 2.0860
# Epoch 25/100
#
# Epoch 00025: val_loss improved from 2.08604 to 2.06080, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 139s - loss: 2.0333 - val_loss: 2.0608
# Epoch 26/100
#
# Epoch 00026: val_loss improved from 2.06080 to 2.03070, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 138s - loss: 2.0034 - val_loss: 2.0307
# Epoch 27/100
#
# Epoch 00027: val_loss improved from 2.03070 to 2.00227, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 140s - loss: 1.9707 - val_loss: 2.0023
# Epoch 28/100
#
# Epoch 00028: val_loss improved from 2.00227 to 1.97041, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 139s - loss: 1.9357 - val_loss: 1.9704
# Epoch 29/100
#
# Epoch 00029: val_loss improved from 1.97041 to 1.93756, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 139s - loss: 1.9006 - val_loss: 1.9376
# Epoch 30/100
#
# Epoch 00030: val_loss improved from 1.93756 to 1.90193, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 142s - loss: 1.8614 - val_loss: 1.9019
# Epoch 31/100
#
# Epoch 00031: val_loss improved from 1.90193 to 1.87030, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 139s - loss: 1.8229 - val_loss: 1.8703
# Epoch 32/100
#
# Epoch 00032: val_loss improved from 1.87030 to 1.85654, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 138s - loss: 1.7864 - val_loss: 1.8565
# Epoch 33/100
#
# Epoch 00033: val_loss improved from 1.85654 to 1.79995, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 138s - loss: 1.7473 - val_loss: 1.7999
# Epoch 34/100
#
# Epoch 00034: val_loss improved from 1.79995 to 1.76152, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 139s - loss: 1.7022 - val_loss: 1.7615
# Epoch 35/100
#
# Epoch 00035: val_loss improved from 1.76152 to 1.72010, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 139s - loss: 1.6607 - val_loss: 1.7201
# Epoch 36/100
#
# Epoch 00036: val_loss improved from 1.72010 to 1.69410, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 138s - loss: 1.6232 - val_loss: 1.6941
# Epoch 37/100
#
# Epoch 00037: val_loss improved from 1.69410 to 1.66235, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 140s - loss: 1.5879 - val_loss: 1.6623
# Epoch 38/100
#
# Epoch 00038: val_loss improved from 1.66235 to 1.63230, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 142s - loss: 1.5538 - val_loss: 1.6323
# Epoch 39/100
#
# Epoch 00039: val_loss improved from 1.63230 to 1.60793, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 139s - loss: 1.5210 - val_loss: 1.6079
# Epoch 40/100
#
# Epoch 00040: val_loss improved from 1.60793 to 1.58158, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 139s - loss: 1.4918 - val_loss: 1.5816
# Epoch 41/100
#
# Epoch 00041: val_loss improved from 1.58158 to 1.55865, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 139s - loss: 1.4609 - val_loss: 1.5587
# Epoch 42/100
#
# Epoch 00042: val_loss improved from 1.55865 to 1.53279, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 139s - loss: 1.4326 - val_loss: 1.5328
# Epoch 43/100
#
# Epoch 00043: val_loss improved from 1.53279 to 1.51246, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 140s - loss: 1.4061 - val_loss: 1.5125
# Epoch 44/100
#
# Epoch 00044: val_loss improved from 1.51246 to 1.49226, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 139s - loss: 1.3803 - val_loss: 1.4923
# Epoch 45/100
#
# Epoch 00045: val_loss improved from 1.49226 to 1.47472, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 139s - loss: 1.3540 - val_loss: 1.4747
# Epoch 46/100
#
# Epoch 00046: val_loss improved from 1.47472 to 1.45058, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 139s - loss: 1.3273 - val_loss: 1.4506
# Epoch 47/100
#
# Epoch 00047: val_loss improved from 1.45058 to 1.42755, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 140s - loss: 1.3026 - val_loss: 1.4276
# Epoch 48/100
#
# Epoch 00048: val_loss improved from 1.42755 to 1.40839, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 139s - loss: 1.2742 - val_loss: 1.4084
# Epoch 49/100
#
# Epoch 00049: val_loss improved from 1.40839 to 1.38758, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 140s - loss: 1.2493 - val_loss: 1.3876
# Epoch 50/100
#
# Epoch 00050: val_loss improved from 1.38758 to 1.36931, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 139s - loss: 1.2240 - val_loss: 1.3693
# Epoch 51/100
#
# Epoch 00051: val_loss improved from 1.36931 to 1.34802, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 139s - loss: 1.1989 - val_loss: 1.3480
# Epoch 52/100
#
# Epoch 00052: val_loss improved from 1.34802 to 1.33270, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 139s - loss: 1.1750 - val_loss: 1.3327
# Epoch 53/100
#
# Epoch 00053: val_loss improved from 1.33270 to 1.31383, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 139s - loss: 1.1516 - val_loss: 1.3138
# Epoch 54/100
#
# Epoch 00054: val_loss improved from 1.31383 to 1.29845, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 138s - loss: 1.1288 - val_loss: 1.2985
# Epoch 55/100
#
# Epoch 00055: val_loss improved from 1.29845 to 1.27811, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 139s - loss: 1.1056 - val_loss: 1.2781
# Epoch 56/100
#
# Epoch 00056: val_loss improved from 1.27811 to 1.26127, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 139s - loss: 1.0837 - val_loss: 1.2613
# Epoch 57/100
#
# Epoch 00057: val_loss improved from 1.26127 to 1.24698, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 139s - loss: 1.0637 - val_loss: 1.2470
# Epoch 58/100
#
# Epoch 00058: val_loss improved from 1.24698 to 1.22908, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 139s - loss: 1.0426 - val_loss: 1.2291
# Epoch 59/100
#
# Epoch 00059: val_loss improved from 1.22908 to 1.21413, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 139s - loss: 1.0184 - val_loss: 1.2141
# Epoch 60/100
#
# Epoch 00060: val_loss improved from 1.21413 to 1.19859, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 139s - loss: 0.9967 - val_loss: 1.1986
# Epoch 61/100
#
# Epoch 00061: val_loss improved from 1.19859 to 1.18212, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 140s - loss: 0.9759 - val_loss: 1.1821
# Epoch 62/100
#
# Epoch 00062: val_loss improved from 1.18212 to 1.17061, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 139s - loss: 0.9554 - val_loss: 1.1706
# Epoch 63/100
#
# Epoch 00063: val_loss improved from 1.17061 to 1.15457, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 138s - loss: 0.9364 - val_loss: 1.1546
# Epoch 64/100
#
# Epoch 00064: val_loss improved from 1.15457 to 1.13895, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 137s - loss: 0.9170 - val_loss: 1.1389
# Epoch 65/100
#
# Epoch 00065: val_loss improved from 1.13895 to 1.12533, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 136s - loss: 0.8972 - val_loss: 1.1253
# Epoch 66/100
#
# Epoch 00066: val_loss improved from 1.12533 to 1.11423, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 138s - loss: 0.8779 - val_loss: 1.1142
# Epoch 67/100
#
# Epoch 00067: val_loss improved from 1.11423 to 1.10310, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 138s - loss: 0.8598 - val_loss: 1.1031
# Epoch 68/100
#
# Epoch 00068: val_loss improved from 1.10310 to 1.08876, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 139s - loss: 0.8406 - val_loss: 1.0888
# Epoch 69/100
#
# Epoch 00069: val_loss improved from 1.08876 to 1.07771, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 138s - loss: 0.8234 - val_loss: 1.0777
# Epoch 70/100
#
# Epoch 00070: val_loss improved from 1.07771 to 1.06618, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 140s - loss: 0.8056 - val_loss: 1.0662
# Epoch 71/100
#
# Epoch 00071: val_loss improved from 1.06618 to 1.05569, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 139s - loss: 0.7893 - val_loss: 1.0557
# Epoch 72/100
#
# Epoch 00072: val_loss improved from 1.05569 to 1.04547, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 139s - loss: 0.7717 - val_loss: 1.0455
# Epoch 73/100
#
# Epoch 00073: val_loss improved from 1.04547 to 1.03655, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 140s - loss: 0.7559 - val_loss: 1.0366
# Epoch 74/100
#
# Epoch 00074: val_loss improved from 1.03655 to 1.02549, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 140s - loss: 0.7412 - val_loss: 1.0255
# Epoch 75/100
#
# Epoch 00075: val_loss improved from 1.02549 to 1.01406, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 139s - loss: 0.7254 - val_loss: 1.0141
# Epoch 76/100
#
# Epoch 00076: val_loss improved from 1.01406 to 1.00758, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 139s - loss: 0.7109 - val_loss: 1.0076
# Epoch 77/100
#
# Epoch 00077: val_loss improved from 1.00758 to 0.99850, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 142s - loss: 0.6960 - val_loss: 0.9985
# Epoch 78/100
#
# Epoch 00078: val_loss improved from 0.99850 to 0.99059, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 140s - loss: 0.6812 - val_loss: 0.9906
# Epoch 79/100
#
# Epoch 00079: val_loss improved from 0.99059 to 0.98305, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 139s - loss: 0.6672 - val_loss: 0.9831
# Epoch 80/100
#
# Epoch 00080: val_loss improved from 0.98305 to 0.97493, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 140s - loss: 0.6540 - val_loss: 0.9749
# Epoch 81/100
#
# Epoch 00081: val_loss improved from 0.97493 to 0.96668, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 138s - loss: 0.6404 - val_loss: 0.9667
# Epoch 82/100
#
# Epoch 00082: val_loss improved from 0.96668 to 0.95770, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 138s - loss: 0.6281 - val_loss: 0.9577
# Epoch 83/100
#
# Epoch 00083: val_loss improved from 0.95770 to 0.95750, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 138s - loss: 0.6157 - val_loss: 0.9575
# Epoch 84/100
#
# Epoch 00084: val_loss improved from 0.95750 to 0.94742, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 139s - loss: 0.6042 - val_loss: 0.9474
# Epoch 85/100
#
# Epoch 00085: val_loss improved from 0.94742 to 0.94118, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 139s - loss: 0.5932 - val_loss: 0.9412
# Epoch 86/100
#
# Epoch 00086: val_loss improved from 0.94118 to 0.93711, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 139s - loss: 0.5818 - val_loss: 0.9371
# Epoch 87/100
#
# Epoch 00087: val_loss improved from 0.93711 to 0.93008, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 139s - loss: 0.5705 - val_loss: 0.9301
# Epoch 88/100
#
# Epoch 00088: val_loss improved from 0.93008 to 0.92323, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 139s - loss: 0.5605 - val_loss: 0.9232
# Epoch 89/100
#
# Epoch 00089: val_loss improved from 0.92323 to 0.91957, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 143s - loss: 0.5498 - val_loss: 0.9196
# Epoch 90/100
#
# Epoch 00090: val_loss improved from 0.91957 to 0.91301, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 139s - loss: 0.5407 - val_loss: 0.9130
# Epoch 91/100
#
# Epoch 00091: val_loss improved from 0.91301 to 0.91259, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 139s - loss: 0.5313 - val_loss: 0.9126
# Epoch 92/100
#
# Epoch 00092: val_loss improved from 0.91259 to 0.90567, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 139s - loss: 0.5219 - val_loss: 0.9057
# Epoch 93/100
#
# Epoch 00093: val_loss did not improve from 0.90567
# 90000/90000 - 138s - loss: 0.5150 - val_loss: 0.9073
# Epoch 94/100
#
# Epoch 00094: val_loss improved from 0.90567 to 0.90088, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 140s - loss: 0.5076 - val_loss: 0.9009
# Epoch 95/100
#
# Epoch 00095: val_loss improved from 0.90088 to 0.89525, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 139s - loss: 0.4983 - val_loss: 0.8952
# Epoch 96/100
#
# Epoch 00096: val_loss improved from 0.89525 to 0.89388, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 139s - loss: 0.4897 - val_loss: 0.8939
# Epoch 97/100
#
# Epoch 00097: val_loss improved from 0.89388 to 0.89256, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 139s - loss: 0.4814 - val_loss: 0.8926
# Epoch 98/100
#
# Epoch 00098: val_loss improved from 0.89256 to 0.88812, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 137s - loss: 0.4732 - val_loss: 0.8881
# Epoch 99/100
#
# Epoch 00099: val_loss improved from 0.88812 to 0.88627, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 137s - loss: 0.4656 - val_loss: 0.8863
# Epoch 100/100
#
# Epoch 00100: val_loss improved from 0.88627 to 0.88229, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_dropout_100k_100e.h5
# 90000/90000 - 138s - loss: 0.4592 - val_loss: 0.8823

# %% [markdown]
# ## Overview

# %%
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.savefig(dirname + 'model_deep_dropout_%s_loss.png' % base_name)
plt.show()
