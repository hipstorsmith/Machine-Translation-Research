# %%
# %tensorflow_version 1.x
import pickle as pkl
import numpy as np
import tensorflow as tf
from matplotlib import pyplot as plt
from tensorflow.python.keras.preprocessing.text import Tokenizer
from tensorflow.python.keras.preprocessing.sequence import pad_sequences
from tensorflow.python.keras.utils import to_categorical
from tensorflow.python.keras.utils.vis_utils import plot_model
from tensorflow.python.keras.models import Sequential, Model
from tensorflow.python.keras.layers import LSTM, Dense, Embedding, TimeDistributed, Bidirectional, Input, Concatenate, Attention, RepeatVector, Dropout
from tensorflow.python.keras.layers.core import Permute
from tensorflow.python.keras.callbacks import ModelCheckpoint
import tensorflow.python.keras.backend as K
import gc
import sys
# Out:
# TensorFlow 1.x selected.

# %%
# Imports for colab
from google.colab import drive
drive.mount('/content/gdrive')

dirname = '/content/gdrive/My Drive/Colab Notebooks/'
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# # Preparations for training

# %% [markdown]
# ## Load clean dataset

# %%
def load_clean_sentences(filename):
    return pkl.load(open(filename, 'rb'))

# %% [markdown]
# ## Fit a tokenizer

# %%
def create_tokenizer(lines, num_words=None, filters='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n', lower=True, oov_token=None):
    tokenizer = Tokenizer(num_words=num_words, filters=filters, lower=lower, oov_token=oov_token)
    tokenizer.fit_on_texts(lines)
    return tokenizer

# %% [markdown]
# ## Compute max length of sentence

# %%
def max_length(lines):
    return max(len(line.split()) for line in lines)

# %% [markdown]
# ## Encode and pad sequences

# %%
def encode_sequences(tokenizer, length, lines):
    # Encode sequences
    X = tokenizer.texts_to_sequences(lines)

    # Pad sequences with zeros
    X = pad_sequences(X, maxlen=length, padding='post')

    return X

# %% [markdown]
# ## One-hot encoding

# %% [markdown]
# One-hot encoding is required for target translation, because NN have to predict probability of next word

# %%
def encode_output(sequences, vocab_size):
    y = np.zeros([sequences.shape[0], sequences.shape[1], vocab_size], dtype=np.int8)
    for i in range(sequences.shape[0]):
        y[i] = to_categorical(sequences[i], num_classes=vocab_size, dtype=np.int8)
    return y

# %% [markdown]
# ## Define model

# %%
def define_model(source_vocab, target_vocab, source_timesteps, target_timesteps, n_units):
    #Encoder
    encoder_inputs = Input(shape=(source_timesteps, ))
    embedding = Embedding(source_vocab, n_units, mask_zero=True)(encoder_inputs)
    encoder_lstm_1 = Bidirectional(LSTM(n_units, dropout=0.2, recurrent_dropout=0.2, return_sequences=True))(embedding)
    encoder_lstm_2 = Bidirectional(LSTM(n_units, dropout=0.2, recurrent_dropout=0.2, return_sequences=False))(encoder_lstm_1)

    #Decoder
    decoder_inputs = RepeatVector(target_timesteps)(encoder_lstm_2)
    decoder_lstm_1 = LSTM(n_units, return_sequences=True, dropout=0.2, recurrent_dropout=0.2)(decoder_inputs)
    decoder_lstm_2 = LSTM(n_units, return_sequences=True, dropout=0.2, recurrent_dropout=0.2)(decoder_lstm_1)
    decoder_lstm_3 = LSTM(n_units, return_sequences=True, dropout=0.2, recurrent_dropout=0.2)(decoder_lstm_2)
    decoder_lstm_4 = LSTM(2*n_units, return_sequences=True, dropout=0.2, recurrent_dropout=0.2)(decoder_lstm_3)
  
    #Attention
    attention = Attention()([decoder_lstm_4, encoder_lstm_1])
    attention_dropout = Dropout(0.3)(attention)
    decoder_lstm_attention = Concatenate(trainable=False)([decoder_lstm_4, attention_dropout])

    decoder_out = TimeDistributed(Dense(target_vocab, activation='softmax'))(decoder_lstm_attention)

    model = Model(inputs=encoder_inputs, outputs=decoder_out)
    return model

# %% [markdown]
# # Training
# X - data, y - target

# %%
# Load datasets

dataset = load_clean_sentences(dirname + 'english-russian-100k-both.pkl')
len_data = len(dataset)
train = load_clean_sentences(dirname + 'english-russian-100k-train.pkl')
test = load_clean_sentences(dirname + 'english-russian-100k-test.pkl')

# %%
# Prepare english tokenizer
base_tok_name = str(len_data//1000) + 'k'

eng_tokenizer = create_tokenizer(dataset[:, 0])
eng_vocab_size = len(eng_tokenizer.word_index) + 1 #+1 because of <EOS> token
eng_length = max_length(dataset[:, 0])
print('English vocabulary size: %d' % eng_vocab_size)
print('English max sentence length: %d' % eng_length)

pkl.dump(eng_tokenizer, open(dirname + 'en_tokenizer_%s' % base_tok_name, 'wb'))
# Out:
# English vocabulary size: 7313
# English max sentence length: 7

# %%
# Prepare russian tokenizer
rus_tokenizer = create_tokenizer(dataset[:, 1])
rus_vocab_size = len(rus_tokenizer.word_index) + 1
rus_length = max_length(dataset[:, 1])
print('Russian vocabulary size: %d' % rus_vocab_size)
print('Russian max sentence length: %d' % rus_length)

pkl.dump(rus_tokenizer, open(dirname + 'ru_tokenizer_%s' % base_tok_name, 'wb'))
# Out:
# Russian vocabulary size: 20884
# Russian max sentence length: 11

# %%
# Prepare training data
X_train = encode_sequences(eng_tokenizer, eng_length, train[:, 0])
y_train = encode_sequences(rus_tokenizer, rus_length, train[:, 1])
y_train = encode_output(y_train, rus_vocab_size)

# %%
# Prepare validation data
X_val = encode_sequences(eng_tokenizer, eng_length, test[:, 0])
y_val = encode_sequences(rus_tokenizer, rus_length, test[:, 1])
y_val = encode_output(y_val, rus_vocab_size)

# %%
#Clean-up some memory
del dataset, train, test

# %%
# Define model
K.clear_session()
model = define_model(eng_vocab_size, rus_vocab_size, eng_length, rus_length, 256)
model.compile(optimizer='adam', loss='categorical_crossentropy')
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/keras/initializers.py:119: calling RandomUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/init_ops.py:97: calling Orthogonal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/keras/backend.py:3994: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
# Model overview
print(model.summary())
plot_model(model, to_file=dirname + 'model_deep_attention_do_rdo.png', show_shapes=True)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 7)]          0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 7, 256)       1872128     input_1[0][0]
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   (None, 7, 512)       1050624     embedding[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 512)          1574912     bidirectional[0][0]
# __________________________________________________________________________________________________
# repeat_vector (RepeatVector)    (None, 11, 512)      0           bidirectional_1[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   (None, 11, 256)      787456      repeat_vector[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   (None, 11, 256)      525312      lstm_2[0][0]
# __________________________________________________________________________________________________
# lstm_4 (LSTM)                   (None, 11, 256)      525312      lstm_3[0][0]
# __________________________________________________________________________________________________
# lstm_5 (LSTM)                   (None, 11, 512)      1574912     lstm_4[0][0]
# __________________________________________________________________________________________________
# attention (Attention)           (None, 11, 512)      0           lstm_5[0][0]
#                                                                  bidirectional[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 11, 512)      0           attention[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 11, 1024)     0           lstm_5[0][0]
#                                                                  dropout[0][0]
# __________________________________________________________________________________________________
# time_distributed (TimeDistribut (None, 11, 20884)    21406100    concatenate[0][0]
# ==================================================================================================
# Total params: 29,316,756
# Trainable params: 29,316,756
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
gc.collect()
# Out:
# 4655

# %%
#Fit model
epochs = 100
base_name = '%dk_%de' % ((len_data//1000, epochs))

filename = dirname + 'model_deep_attention_do_rdo_%s.h5' % base_name
checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
history = model.fit(X_train, y_train, epochs=epochs, batch_size=512, validation_data=(X_val, y_val), callbacks=[checkpoint], verbose=2)
# Out:
# Train on 90000 samples, validate on 10000 samples
# Epoch 1/100
#
# Epoch 00001: val_loss improved from inf to 2.08773, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_attention_do_rdo_100k_100e.h5
# 90000/90000 - 119s - loss: 2.8689 - val_loss: 2.0877
# Epoch 2/100
#
# Epoch 00002: val_loss improved from 2.08773 to 1.75186, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_attention_do_rdo_100k_100e.h5
# 90000/90000 - 106s - loss: 1.9206 - val_loss: 1.7519
# Epoch 3/100
#
# Epoch 00003: val_loss improved from 1.75186 to 1.52394, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_attention_do_rdo_100k_100e.h5
# 90000/90000 - 104s - loss: 1.6100 - val_loss: 1.5239
# Epoch 4/100
#
# Epoch 00004: val_loss improved from 1.52394 to 1.35206, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_attention_do_rdo_100k_100e.h5
# 90000/90000 - 105s - loss: 1.3828 - val_loss: 1.3521
# Epoch 5/100
#
# Epoch 00005: val_loss improved from 1.35206 to 1.22076, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_attention_do_rdo_100k_100e.h5
# 90000/90000 - 104s - loss: 1.2046 - val_loss: 1.2208
# Epoch 6/100
#
# Epoch 00006: val_loss improved from 1.22076 to 1.11941, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_attention_do_rdo_100k_100e.h5
# 90000/90000 - 106s - loss: 1.0590 - val_loss: 1.1194
# Epoch 7/100
#
# Epoch 00007: val_loss improved from 1.11941 to 1.04219, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_attention_do_rdo_100k_100e.h5
# 90000/90000 - 106s - loss: 0.9397 - val_loss: 1.0422
# Epoch 8/100
#
# Epoch 00008: val_loss improved from 1.04219 to 0.98588, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_attention_do_rdo_100k_100e.h5
# 90000/90000 - 105s - loss: 0.8470 - val_loss: 0.9859
# Epoch 9/100
#
# Epoch 00009: val_loss improved from 0.98588 to 0.94332, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_attention_do_rdo_100k_100e.h5
# 90000/90000 - 105s - loss: 0.7726 - val_loss: 0.9433
# Epoch 10/100
#
# Epoch 00010: val_loss improved from 0.94332 to 0.91161, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_attention_do_rdo_100k_100e.h5
# 90000/90000 - 107s - loss: 0.7138 - val_loss: 0.9116
# Epoch 11/100
#
# Epoch 00011: val_loss improved from 0.91161 to 0.88739, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_attention_do_rdo_100k_100e.h5
# 90000/90000 - 105s - loss: 0.6689 - val_loss: 0.8874
# Epoch 12/100
#
# Epoch 00012: val_loss improved from 0.88739 to 0.86939, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_attention_do_rdo_100k_100e.h5
# 90000/90000 - 106s - loss: 0.6321 - val_loss: 0.8694
# Epoch 13/100
#
# Epoch 00013: val_loss improved from 0.86939 to 0.86762, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_attention_do_rdo_100k_100e.h5
# 90000/90000 - 105s - loss: 0.6035 - val_loss: 0.8676
# Epoch 14/100
#
# Epoch 00014: val_loss improved from 0.86762 to 0.84774, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_attention_do_rdo_100k_100e.h5
# 90000/90000 - 110s - loss: 0.5810 - val_loss: 0.8477
# Epoch 15/100
#
# Epoch 00015: val_loss improved from 0.84774 to 0.83875, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_attention_do_rdo_100k_100e.h5
# 90000/90000 - 107s - loss: 0.5578 - val_loss: 0.8388
# Epoch 16/100
#
# Epoch 00016: val_loss improved from 0.83875 to 0.82942, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_attention_do_rdo_100k_100e.h5
# 90000/90000 - 106s - loss: 0.5402 - val_loss: 0.8294
# Epoch 17/100
#
# Epoch 00017: val_loss improved from 0.82942 to 0.82741, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_attention_do_rdo_100k_100e.h5
# 90000/90000 - 105s - loss: 0.5249 - val_loss: 0.8274
# Epoch 18/100
#
# Epoch 00018: val_loss improved from 0.82741 to 0.81951, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_attention_do_rdo_100k_100e.h5
# 90000/90000 - 108s - loss: 0.5116 - val_loss: 0.8195
# Epoch 19/100
#
# Epoch 00019: val_loss improved from 0.81951 to 0.81453, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_attention_do_rdo_100k_100e.h5
# 90000/90000 - 105s - loss: 0.4984 - val_loss: 0.8145
# Epoch 20/100
#
# Epoch 00020: val_loss improved from 0.81453 to 0.81167, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_attention_do_rdo_100k_100e.h5
# 90000/90000 - 108s - loss: 0.4881 - val_loss: 0.8117
# Epoch 21/100
#
# Epoch 00021: val_loss improved from 0.81167 to 0.81063, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_attention_do_rdo_100k_100e.h5
# 90000/90000 - 105s - loss: 0.4775 - val_loss: 0.8106
# Epoch 22/100
#
# Epoch 00022: val_loss improved from 0.81063 to 0.80875, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_attention_do_rdo_100k_100e.h5
# 90000/90000 - 105s - loss: 0.4683 - val_loss: 0.8087
# Epoch 23/100
#
# Epoch 00023: val_loss improved from 0.80875 to 0.80489, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_attention_do_rdo_100k_100e.h5
# 90000/90000 - 105s - loss: 0.4599 - val_loss: 0.8049
# Epoch 24/100
#
# Epoch 00024: val_loss did not improve from 0.80489
# 90000/90000 - 103s - loss: 0.4518 - val_loss: 0.8057
# Epoch 25/100
#
# Epoch 00025: val_loss improved from 0.80489 to 0.80478, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_attention_do_rdo_100k_100e.h5
# 90000/90000 - 104s - loss: 0.4436 - val_loss: 0.8048
# Epoch 26/100
#
# Epoch 00026: val_loss improved from 0.80478 to 0.80093, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_attention_do_rdo_100k_100e.h5
# 90000/90000 - 105s - loss: 0.4360 - val_loss: 0.8009
# Epoch 27/100
#
# Epoch 00027: val_loss improved from 0.80093 to 0.79921, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_attention_do_rdo_100k_100e.h5
# 90000/90000 - 106s - loss: 0.4283 - val_loss: 0.7992
# Epoch 28/100
#
# Epoch 00028: val_loss improved from 0.79921 to 0.79919, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_attention_do_rdo_100k_100e.h5
# 90000/90000 - 104s - loss: 0.4220 - val_loss: 0.7992
# Epoch 29/100
#
# Epoch 00029: val_loss improved from 0.79919 to 0.79825, saving model to /content/gdrive/My Drive/Colab Notebooks/model_deep_attention_do_rdo_100k_100e.h5
# 90000/90000 - 106s - loss: 0.4166 - val_loss: 0.7983
# Epoch 30/100
#
# Epoch 00030: val_loss did not improve from 0.79825
# 90000/90000 - 102s - loss: 0.4092 - val_loss: 0.7998
# Epoch 31/100
#
# Epoch 00031: val_loss did not improve from 0.79825
# 90000/90000 - 103s - loss: 0.4039 - val_loss: 0.7996
# Epoch 32/100
#
# Epoch 00032: val_loss did not improve from 0.79825
# 90000/90000 - 102s - loss: 0.3995 - val_loss: 0.8020
# Epoch 33/100
#
# Epoch 00033: val_loss did not improve from 0.79825
# 90000/90000 - 99s - loss: 0.3940 - val_loss: 0.7993
# Epoch 34/100
#
# Epoch 00034: val_loss did not improve from 0.79825
# 90000/90000 - 100s - loss: 0.3892 - val_loss: 0.8002
# Epoch 35/100
#
# Epoch 00035: val_loss did not improve from 0.79825
# 90000/90000 - 99s - loss: 0.3852 - val_loss: 0.8001
# Epoch 36/100
#
# Epoch 00036: val_loss did not improve from 0.79825
# 90000/90000 - 99s - loss: 0.3809 - val_loss: 0.8017
# Epoch 37/100
#
# Epoch 00037: val_loss did not improve from 0.79825
# 90000/90000 - 100s - loss: 0.3765 - val_loss: 0.8015
# Epoch 38/100
#
# Epoch 00038: val_loss did not improve from 0.79825
# 90000/90000 - 99s - loss: 0.3728 - val_loss: 0.8024
# Epoch 39/100
#
# Epoch 00039: val_loss did not improve from 0.79825
# 90000/90000 - 99s - loss: 0.3696 - val_loss: 0.8045
# Epoch 40/100
#
# Epoch 00040: val_loss did not improve from 0.79825
# 90000/90000 - 99s - loss: 0.3653 - val_loss: 0.8031
# Epoch 41/100
#
# Epoch 00041: val_loss did not improve from 0.79825
# 90000/90000 - 99s - loss: 0.3617 - val_loss: 0.8080
# Epoch 42/100
#
# Epoch 00042: val_loss did not improve from 0.79825
# 90000/90000 - 99s - loss: 0.3578 - val_loss: 0.8056
# Epoch 43/100
#
# Epoch 00043: val_loss did not improve from 0.79825
# 90000/90000 - 100s - loss: 0.3553 - val_loss: 0.8053
# Epoch 44/100
#
# Epoch 00044: val_loss did not improve from 0.79825
# 90000/90000 - 99s - loss: 0.3520 - val_loss: 0.8098
# Epoch 45/100
#
# Epoch 00045: val_loss did not improve from 0.79825
# 90000/90000 - 99s - loss: 0.3493 - val_loss: 0.8083
# Epoch 46/100
#
# Epoch 00046: val_loss did not improve from 0.79825
# 90000/90000 - 99s - loss: 0.3473 - val_loss: 0.8079
# Epoch 47/100
#
# Epoch 00047: val_loss did not improve from 0.79825
# 90000/90000 - 99s - loss: 0.3430 - val_loss: 0.8086
# Epoch 48/100
#
# Epoch 00048: val_loss did not improve from 0.79825
# 90000/90000 - 99s - loss: 0.3414 - val_loss: 0.8134
# Epoch 49/100
#
# Epoch 00049: val_loss did not improve from 0.79825
# 90000/90000 - 99s - loss: 0.3381 - val_loss: 0.8138
# Epoch 50/100
#
# Epoch 00050: val_loss did not improve from 0.79825
# 90000/90000 - 99s - loss: 0.3363 - val_loss: 0.8162
# Epoch 51/100
#
# Epoch 00051: val_loss did not improve from 0.79825
# 90000/90000 - 99s - loss: 0.3340 - val_loss: 0.8154
# Epoch 52/100
#
# Epoch 00052: val_loss did not improve from 0.79825
# 90000/90000 - 99s - loss: 0.3315 - val_loss: 0.8152
# Epoch 53/100
#
# Epoch 00053: val_loss did not improve from 0.79825
# 90000/90000 - 99s - loss: 0.3298 - val_loss: 0.8163
# Epoch 54/100
#
# Epoch 00054: val_loss did not improve from 0.79825
# 90000/90000 - 99s - loss: 0.3274 - val_loss: 0.8191
# Epoch 55/100
#
# Epoch 00055: val_loss did not improve from 0.79825
# 90000/90000 - 99s - loss: 0.3253 - val_loss: 0.8200
# Epoch 56/100
#
# Epoch 00056: val_loss did not improve from 0.79825
# 90000/90000 - 98s - loss: 0.3232 - val_loss: 0.8214
# Epoch 57/100
#
# Epoch 00057: val_loss did not improve from 0.79825
# 90000/90000 - 98s - loss: 0.3215 - val_loss: 0.8222
# Epoch 58/100
#
# Epoch 00058: val_loss did not improve from 0.79825
# 90000/90000 - 96s - loss: 0.3193 - val_loss: 0.8258
# Epoch 59/100
#
# Epoch 00059: val_loss did not improve from 0.79825
# 90000/90000 - 95s - loss: 0.3182 - val_loss: 0.8269
# Epoch 60/100
#
# Epoch 00060: val_loss did not improve from 0.79825
# 90000/90000 - 95s - loss: 0.3157 - val_loss: 0.8235
# Epoch 61/100
#
# Epoch 00061: val_loss did not improve from 0.79825
# 90000/90000 - 94s - loss: 0.3140 - val_loss: 0.8329
# Epoch 62/100
#
# Epoch 00062: val_loss did not improve from 0.79825
# 90000/90000 - 95s - loss: 0.3123 - val_loss: 0.8278
# Epoch 63/100
#
# Epoch 00063: val_loss did not improve from 0.79825
# 90000/90000 - 94s - loss: 0.3105 - val_loss: 0.8297
# Epoch 64/100
#
# Epoch 00064: val_loss did not improve from 0.79825
# 90000/90000 - 94s - loss: 0.3078 - val_loss: 0.8319
# Epoch 65/100
#
# Epoch 00065: val_loss did not improve from 0.79825
# 90000/90000 - 94s - loss: 0.3069 - val_loss: 0.8310
# Epoch 66/100
#
# Epoch 00066: val_loss did not improve from 0.79825
# 90000/90000 - 93s - loss: 0.3065 - val_loss: 0.8338
# Epoch 67/100
#
# Epoch 00067: val_loss did not improve from 0.79825
# 90000/90000 - 93s - loss: 0.3044 - val_loss: 0.8323
# Epoch 68/100
#
# Epoch 00068: val_loss did not improve from 0.79825
# 90000/90000 - 93s - loss: 0.3038 - val_loss: 0.8364
# Epoch 69/100
#
# Epoch 00069: val_loss did not improve from 0.79825
# 90000/90000 - 94s - loss: 0.3009 - val_loss: 0.8335
# Epoch 70/100
#
# Epoch 00070: val_loss did not improve from 0.79825
# 90000/90000 - 93s - loss: 0.2998 - val_loss: 0.8349
# Epoch 71/100
#
# Epoch 00071: val_loss did not improve from 0.79825
# 90000/90000 - 93s - loss: 0.2984 - val_loss: 0.8359
# Epoch 72/100
#
# Epoch 00072: val_loss did not improve from 0.79825
# 90000/90000 - 93s - loss: 0.2976 - val_loss: 0.8397
# Epoch 73/100
#
# Epoch 00073: val_loss did not improve from 0.79825
# 90000/90000 - 93s - loss: 0.2954 - val_loss: 0.8398
# Epoch 74/100
#
# Epoch 00074: val_loss did not improve from 0.79825
# 90000/90000 - 94s - loss: 0.2943 - val_loss: 0.8373
# Epoch 75/100
#
# Epoch 00075: val_loss did not improve from 0.79825
# 90000/90000 - 93s - loss: 0.2941 - val_loss: 0.8433
# Epoch 76/100
#
# Epoch 00076: val_loss did not improve from 0.79825
# 90000/90000 - 93s - loss: 0.2913 - val_loss: 0.8415
# Epoch 77/100
#
# Epoch 00077: val_loss did not improve from 0.79825
# 90000/90000 - 93s - loss: 0.2904 - val_loss: 0.8407
# Epoch 78/100
#
# Epoch 00078: val_loss did not improve from 0.79825
# 90000/90000 - 93s - loss: 0.2900 - val_loss: 0.8438
# Epoch 79/100
#
# Epoch 00079: val_loss did not improve from 0.79825
# 90000/90000 - 93s - loss: 0.2884 - val_loss: 0.8433
# Epoch 80/100
#
# Epoch 00080: val_loss did not improve from 0.79825
# 90000/90000 - 93s - loss: 0.2875 - val_loss: 0.8426
# Epoch 81/100
#
# Epoch 00081: val_loss did not improve from 0.79825
# 90000/90000 - 93s - loss: 0.2865 - val_loss: 0.8420
# Epoch 82/100
#
# Epoch 00082: val_loss did not improve from 0.79825
# 90000/90000 - 93s - loss: 0.2861 - val_loss: 0.8482
# Epoch 83/100
#
# Epoch 00083: val_loss did not improve from 0.79825
# 90000/90000 - 93s - loss: 0.2847 - val_loss: 0.8478
# Epoch 84/100
#
# Epoch 00084: val_loss did not improve from 0.79825
# 90000/90000 - 93s - loss: 0.2843 - val_loss: 0.8485
# Epoch 85/100
#
# Epoch 00085: val_loss did not improve from 0.79825
# 90000/90000 - 93s - loss: 0.2814 - val_loss: 0.8501
# Epoch 86/100
#
# Epoch 00086: val_loss did not improve from 0.79825
# 90000/90000 - 93s - loss: 0.2806 - val_loss: 0.8500
# Epoch 87/100
#
# Epoch 00087: val_loss did not improve from 0.79825
# 90000/90000 - 93s - loss: 0.2803 - val_loss: 0.8505
# Epoch 88/100
#
# Epoch 00088: val_loss did not improve from 0.79825
# 90000/90000 - 93s - loss: 0.2778 - val_loss: 0.8509
# Epoch 89/100
#
# Epoch 00089: val_loss did not improve from 0.79825
# 90000/90000 - 94s - loss: 0.2786 - val_loss: 0.8508
# Epoch 90/100
#
# Epoch 00090: val_loss did not improve from 0.79825
# 90000/90000 - 93s - loss: 0.2777 - val_loss: 0.8509
# Epoch 91/100
#
# Epoch 00091: val_loss did not improve from 0.79825
# 90000/90000 - 93s - loss: 0.2762 - val_loss: 0.8542
# Epoch 92/100
#
# Epoch 00092: val_loss did not improve from 0.79825
# 90000/90000 - 92s - loss: 0.2755 - val_loss: 0.8543
# Epoch 93/100
#
# Epoch 00093: val_loss did not improve from 0.79825
# 90000/90000 - 92s - loss: 0.2750 - val_loss: 0.8554
# Epoch 94/100
#
# Epoch 00094: val_loss did not improve from 0.79825
# 90000/90000 - 91s - loss: 0.2738 - val_loss: 0.8565
# Epoch 95/100
#
# Epoch 00095: val_loss did not improve from 0.79825
# 90000/90000 - 91s - loss: 0.2728 - val_loss: 0.8586
# Epoch 96/100
#
# Epoch 00096: val_loss did not improve from 0.79825
# 90000/90000 - 91s - loss: 0.2723 - val_loss: 0.8602
# Epoch 97/100
#
# Epoch 00097: val_loss did not improve from 0.79825
# 90000/90000 - 91s - loss: 0.2711 - val_loss: 0.8635
# Epoch 98/100
#
# Epoch 00098: val_loss did not improve from 0.79825
# 90000/90000 - 91s - loss: 0.2706 - val_loss: 0.8592
# Epoch 99/100
#
# Epoch 00099: val_loss did not improve from 0.79825
# 90000/90000 - 91s - loss: 0.2703 - val_loss: 0.8595
# Epoch 100/100
#
# Epoch 00100: val_loss did not improve from 0.79825
# 90000/90000 - 91s - loss: 0.2691 - val_loss: 0.8634

# %% [markdown]
# ## Overview

# %%
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.savefig(dirname + 'model_deep_attention_do_rdo_%s_loss.png' % base_name)
plt.show()
